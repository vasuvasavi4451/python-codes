# %%
import pandas as pd

# %%
survived

# %%
survived.tail()

# %%
# %cd C:\\Users\DELL\Desktop\pyrhon in buss analytics
# Out:
# C:\Users\DELL\Desktop\pyrhon in buss analytics

# %%
survived=pd.read_csv('Titanic1.csv',sep=",")

# %%
survived
# Out:
#       PassengerId  Survived  Pclass  \
# 0             846         0     3.0
# 1            1284         0     NaN
# 2             747         0     3.0
# 3             280         1     3.0
# 4            1237         1     NaN
# 5             949         1     NaN
# 6             309         0     2.0
# 7             875         1     2.0
# 8            1143         1     NaN
# 9             900         1     NaN
# 10            366         0     3.0
# 11            402         0     3.0
# 12             41         0     3.0
# 13           1199         0     NaN
# 14            856         0     3.0
# 15            208         1     3.0
# 16            970         1     NaN
# 17            811         0     3.0
# 18            841         0     3.0
# 19            211         0     3.0
# 20            785         0     3.0
# 21            731         1     1.0
# 22              5         0     3.0
# 23            306         1     1.0
# 24            298         0     1.0
# ...

# %%
survived.tail()
# Out:
#       PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 1304          112         0     3.0       Zabour, Miss. Hileni  female  14.5
# 1305          241         0     3.0      Zabour, Miss. Thamine  female   NaN
# 1306         1028         0     NaN  Zakarian, Mr. Mapriededer    male  26.5
# 1307         1063         0     NaN        Zakarian, Mr. Ortin    male  27.0
# 1308          423         0     3.0         Zimmerman, Mr. Leo    male  29.0
#
#       SibSp  Parch  Ticket     Fare Cabin Embarked
# 1304      1      0    2665  14.4542   NaN        C
# 1305      1      0    2665  14.4542   NaN        C
# 1306      0      0    2656   7.2250   NaN        C
# 1307      0      0    2670   7.2250   NaN        C
# 1308      0      0  315082   7.8750   NaN        S

# %%
survived.head()
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          846         0     3.0               Abbing, Mr. Anthony    male
# 1         1284         0     NaN     Abbott, Master. Eugene Joseph    male
# 2          747         0     3.0       Abbott, Mr. Rossmore Edward    male
# 3          280         1     3.0  Abbott, Mrs. Stanton (Rosa Hunt)  female
# 4         1237         1     NaN       Abelseth, Miss. Karen Marie  female
#
#     Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 0  42.0      0      0  C.A. 5547   7.55   NaN        S
# 1  13.0      0      2  C.A. 2673  20.25   NaN        S
# 2  16.0      1      1  C.A. 2673  20.25   NaN        S
# 3  35.0      1      1  C.A. 2673  20.25   NaN        S
# 4  16.0      0      0     348125   7.65   NaN        S

# %%
survived['SibSp'].value_counts()
# Out:
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %%
survived['SibSp'].describe()
# Out:
# count    1309.000000
# mean        0.498854
# std         1.041658
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         8.000000
# Name: SibSp, dtype: float64

# %% [markdown]
# ####survival rate for passengers

# %% [markdown]
# ### mean on survived  only applicable becuase it is ones and zeros

# %%
survived['Survived'].mean() ## in this case o's and 1's applicable not on others
# Out:
# 0.3430099312452254

# %% [markdown]
# ### split combine and apply method

# %% [markdown]
# ### groupby groups the data

# %%
survived.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1.0    0.435185
# 2.0    0.331522
# 3.0    0.281059
# Name: Survived, dtype: float64

# %%
survived.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.341202
# male      0.344009
# Name: Survived, dtype: float64

# %%
survived.groupby(['Sex','Pclass'])['Survived'].mean()
# Out:
# Sex     Pclass
# female  1.0       0.425532
#         2.0       0.394737
#         3.0       0.243056
# male    1.0       0.442623
#         2.0       0.287037
#         3.0       0.296830
# Name: Survived, dtype: float64

# %%
survived.groupby('Parch')['Survived'].mean()
# Out:
# Parch
# 0    0.333333
# 1    0.376471
# 2    0.362832
# 3    0.625000
# 4    0.333333
# 5    0.166667
# 6    0.500000
# 9    0.500000
# Name: Survived, dtype: float64

# %%
survived.groupby('SibSp')['Survived'].mean()
# Out:
# SibSp
# 0    0.333333
# 1    0.398119
# 2    0.404762
# 3    0.200000
# 4    0.090909
# 5    0.166667
# 8    0.111111
# Name: Survived, dtype: float64

# %%
survived['Age'].describe()   ### mean is avg
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### creating age group variable and see survival rate

# %% [markdown]
# ### creating family grop variable dummy variable

# %%
survived.groupby(['Pclass','Sex'])['Age'].agg(['min','max','mean'])  ##  aggregate takes name and converts in to function
# Out:
#                 min   max       mean
# Pclass Sex
# 1.0    female  2.00  63.0  34.611765
#        male    0.92  80.0  41.281386
# 2.0    female  2.00  57.0  28.722973
#        male    0.67  70.0  30.740707
# 3.0    female  0.75  63.0  21.750000
#        male    0.42  74.0  26.507589

# %%
survived.groupby(['Pclass'])['Fare'].agg(['min','max','mean'])
# Out:
#         min       max       mean
# Pclass
# 1.0     0.0  512.3292  84.154687
# 2.0     0.0   73.5000  20.662183
# 3.0     0.0   69.5500  13.675550

# %%
survived.['Fare']==0
# Out:
#   File "<ipython-input-29-aaa863bd9b5a>", line 1
#     survived.['Fare']==0
#              ^
# SyntaxError: invalid syntax

# %%
survived.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# PassengerId    1309 non-null int64
# Survived       1309 non-null int64
# Pclass         891 non-null float64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
survived[survived.Fare=='0']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-5fbbe1e2c1b3> in <module>
# ----> 1 survived[survived.survived_Fare=='0']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'survived_Fare'

# %% [markdown]
# #### numeric in to crete categoric variable and do groupby and crosstabs

# %% [markdown]
# ##### variable data dictionary syntax
