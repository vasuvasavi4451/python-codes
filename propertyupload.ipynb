# %%
import pandas as pd
import numpy as np

# %%
# %cd C:\\Users\DELL\Desktop\pyrhon in buss analytics
# Out:
# C:\Users\DELL\Desktop\pyrhon in buss analytics

# %%
# %pwd
# Out:
# 'C:\\Users\\DELL\\Desktop\\pyrhon in buss analytics'

# %%
prop=pd.read_csv('property.csv')

# %%
prop
# Out:
#             PID  PINCODE              AREA NAME OWN_OCCUPIED NUM_BEDROOMS  \
# 0   100001000.0    560087                VARTUR            Y            3
# 1   100002000.0    560103             BELLANDUR            N            3
# 2   100003000.0    560067          KANNAMANGALA            N          NaN
# 3   100004000.0    560049                MUNDUR            N            1
# 4           NaN    560049            BIDRAHALLI            Y            3
# 5   100006000.0    560067              KADUGODI            Y          NaN
# 6   100007000.0    560087           MUTHUSANDRA          NaN            2
# 7   100008000.0    560067           DEVANAGUNDI            Y            1
# 8   100009000.0    560067       MEDIMALLASANDRA            Y           na
# 9   100010000.0    560066            WHITEFIELD            Y            3
# 10  100011000.0    560037               YEMALUR            N            3
# 11  100012000.0    560007                 AGRAM            N            3
# ...

# %%
fix =prop

# %%
fix['num_bedrooms']=fix["NUM_BEDROOMS"].fillna(2)

# %%
fix
# Out:
#             PID  PINCODE              AREA NAME OWN_OCCUPIED NUM_BEDROOMS  \
# 0   100001000.0    560087                VARTUR            Y            3
# 1   100002000.0    560103             BELLANDUR            N            3
# 2   100003000.0    560067          KANNAMANGALA            N          NaN
# 3   100004000.0    560049                MUNDUR            N            1
# 4           NaN    560049            BIDRAHALLI            Y            3
# 5   100006000.0    560067              KADUGODI            Y          NaN
# 6   100007000.0    560087           MUTHUSANDRA          NaN            2
# 7   100008000.0    560067           DEVANAGUNDI            Y            1
# 8   100009000.0    560067       MEDIMALLASANDRA            Y           na
# 9   100010000.0    560066            WHITEFIELD            Y            3
# 10  100011000.0    560037               YEMALUR            N            3
# 11  100012000.0    560007                 AGRAM            N            3
# ...
