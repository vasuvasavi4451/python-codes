# %%
import pandas as pd

# %%
electors=pd.read_csv('LS2014Electors (1).csv',sep=",")

# %%
electors
# Out:
#     STATE CODE                      STATE  PC NO  \
# 0          S01             Andhra Pradesh      1
# 1          S01             Andhra Pradesh      2
# 2          S01             Andhra Pradesh      3
# 3          S01             Andhra Pradesh      4
# 4          S01             Andhra Pradesh      5
# 5          S01             Andhra Pradesh      6
# 6          S01             Andhra Pradesh      7
# 7          S01             Andhra Pradesh      8
# 8          S01             Andhra Pradesh      9
# 9          S01             Andhra Pradesh     10
# 10         S01             Andhra Pradesh     11
# 11         S01             Andhra Pradesh     12
# 12         S01             Andhra Pradesh     13
# 13         S01             Andhra Pradesh     14
# 14         S01             Andhra Pradesh     15
# 15         S01             Andhra Pradesh     16
# 16         S01             Andhra Pradesh     17
# 17         S01             Andhra Pradesh     18
# ...

# %%
electors['STATE'].describe()### apply describe to individual columns
# Out:
# count               543
# unique               35
# top       Uttar Pradesh
# freq                 80
# Name: STATE, dtype: object

# %% [markdown]
# #### describe function to each column

# %%
electors['STATE CODE'].describe()
# Out:
# count     543
# unique     35
# top       S24
# freq       80
# Name: STATE CODE, dtype: object

# %%
electors['PC NO'].describe()
# Out:
# count    543.000000
# mean      18.968692
# std       16.560438
# min        1.000000
# 25%        6.000000
# 50%       15.000000
# 75%       27.000000
# max       80.000000
# Name: PC NO, dtype: float64

# %%
electors['PARLIAMENTARY CONSTITUENCY'].describe()
# Out:
# count            543
# unique           540
# top       Aurangabad
# freq               2
# Name: PARLIAMENTARY CONSTITUENCY, dtype: object

# %%
electors['Total voters'].describe()
# Out:
# count    5.430000e+02
# mean     1.020581e+06
# std      1.929034e+05
# min      4.324200e+04
# 25%      9.405790e+05
# 50%      1.034032e+06
# 75%      1.130322e+06
# max      1.624859e+06
# Name: Total voters, dtype: float64

# %%
electors['Total_Electors'].describe()
# Out:
# count    5.430000e+02
# mean     1.536064e+06
# std      2.881144e+05
# min      4.992200e+04
# 25%      1.425049e+06
# 50%      1.555781e+06
# 75%      1.694062e+06
# max      3.183083e+06
# Name: Total_Electors, dtype: float64

# %%
electors['POLL PERCENTAGE'].describe()
# Out:
# count    543.000000
# mean      67.319816
# std       10.316871
# min       25.860000
# 25%       59.285000
# 50%       66.750000
# 75%       75.825000
# max       88.360000
# Name: POLL PERCENTAGE, dtype: float64

# %%
electors['STATE CODE'].value_counts()   ### value counts for each column
# Out:
# S24    80
# S13    48
# S25    42
# S01    42
# S04    40
# S22    39
# S12    29
# S10    28
# S06    26
# S20    25
# S18    21
# S11    20
# S03    14
# S27    14
# S19    13
# S26    11
# S07    10
# U05     7
# S09     6
# S28     5
# S08     4
# S02     2
# S23     2
# S05     2
# S14     2
# S15     2
# S16     1
# U04     1
# U03     1
# U06     1
# U02     1
# S21     1
# U01     1
# U07     1
# S17     1
# Name: STATE CODE, dtype: int64

# %%
electors['STATE'].value_counts()
# Out:
# Uttar Pradesh                80
# Maharashtra                  48
# West Bengal                  42
# Andhra Pradesh               42
# Bihar                        40
# Tamil Nadu                   39
# Madhya Pradesh               29
# Karnataka                    28
# Gujarat                      26
# Rajasthan                    25
# Odisha                       21
# Kerala                       20
# Jharkhand                    14
# Assam                        14
# Punjab                       13
# Chhattisgarh                 11
# Haryana                      10
# NCT OF Delhi                  7
# Jammu & Kashmir               6
# Uttarakhand                   5
# Himachal Pradesh              4
# Arunachal Pradesh             2
# Tripura                       2
# Meghalaya                     2
# Goa                           2
# Manipur                       2
# Nagaland                      1
# Daman & Diu                   1
# Mizoram                       1
# ...

# %%
electors['PC NO'].value_counts()
# Out:
# 1     35
# 2     26
# 3     21
# 4     21
# 5     20
# 6     19
# 7     18
# 9     17
# 10    17
# 8     17
# 11    16
# 12    15
# 13    15
# 14    14
# 17    12
# 20    12
# 18    12
# 19    12
# 16    12
# 15    12
# 21    11
# 22    10
# 23    10
# 24    10
# 25    10
# 26     9
# 27     8
# 28     8
# 29     7
# 39     6
#       ..
# 66     1
# 67     1
# 68     1
# 69     1
# 70     1
# 75     1
# 72     1
# 73     1
# 74     1
# 64     1
# 76     1
# 77     1
# 78     1
# 65     1
# 60     1
# 63     1
# 62     1
# 61     1
# 59     1
# 58     1
# 57     1
# 56     1
# 55     1
# 54     1
# 53     1
# 52     1
# 51     1
# 50     1
# 49     1
# 80     1
# Name: PC NO, Length: 80, dtype: int64

# %%
electors['PARLIAMENTARY CONSTITUENCY'].value_counts()
# Out:
# Aurangabad              2
# Hamirpur                2
# Maharajganj             2
# Jagatsinghpur           1
# Daman & diu             1
# Ladakh                  1
# Cuddalore               1
# Dibrugarh               1
# Sikkim                  1
# Darjeeling              1
# Banswara                1
# Virudhunagar            1
# Dum dum                 1
# Hyderabad               1
# Ghaziabad               1
# Mathura                 1
# MANDSOUR                1
# Kaliabor                1
# SAGAR                   1
# Saran                   1
# Rajahmundry             1
# Murshidabad             1
# Ongole                  1
# Keonjhar                1
# Nagina                  1
# Nandurbar               1
# Beed                    1
# Baramati                1
# Puri                    1
# Jalna                   1
#                        ..
# Shahjahanpur            1
# Kollam                  1
# Tiruppur                1
# Dhule                   1
# ...

# %%
electors['Total voters'].value_counts()
# Out:
# 1116159    1
# 1197398    1
# 1042748    1
# 1163582    1
# 1250872    1
# 889152     1
# 1212738    1
# 1132868    1
# 947525     1
# 1322312    1
# 1088842    1
# 737611     1
# 884044     1
# 943437     1
# 1209680    1
# 1193041    1
# 969047     1
# 800058     1
# 1088045    1
# 975195     1
# 948572     1
# 310095     1
# 975203     1
# 942568     1
# 1187174    1
# 1125728    1
# 863592     1
# 974187     1
# 1028462    1
# 854281     1
#           ..
# 1369722    1
# 879228     1
# 1027473    1
# 918144     1
# 1007235    1
# 1236613    1
# 1179270    1
# 1117831    1
# 4        S01  Andhra Pradesh      5                  Zahirabad       1099784
#
#    Total_Electors  POLL PERCENTAGE
# 0         1386282            76.15
# 1         1425355            71.93
# 2         1550810            72.69
# 3         1496193            69.11
# 4         1445354            76.09

# %%
electors.tail()
# Out:
#     STATE CODE         STATE  PC NO      PARLIAMENTARY CONSTITUENCY  \
# 538        U05  NCT OF Delhi      5  NORTH WEST DELHI
# 539        U05  NCT OF Delhi      6  WEST DELHI
# 540        U05  NCT OF Delhi      7  SOUTH DELHI
# 541        U06   Lakshadweep      1                     Lakshadweep
# 542        U07    Puducherry      1                      Puducherry
#
#      Total voters  Total_Electors  POLL PERCENTAGE
# 538       1356404         2194343            61.81
# 539       1348744         2039410            66.13
# 540       1102849         1752748            62.92
# 541         43242           49922            86.62
# 542        740053          901357            82.10

# %%
electors.shape
# Out:
# (543, 7)

# %%
electors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 7 columns):
# STATE CODE                    543 non-null object
# STATE                         543 non-null object
# PC NO                         543 non-null int64
# PARLIAMENTARY CONSTITUENCY    543 non-null object
# Total voters                  543 non-null int64
# Total_Electors                543 non-null int64
# POLL PERCENTAGE               543 non-null float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 29.8+ KB

# %%
electors.index
# Out:
# RangeIndex(start=0, stop=543, step=1)

# %%
electors['POLL PERCENTAGE'].sum()
# Out:
# 36554.66

# %%
electors.agg(['min','max','mean'])
# Out:
#      STATE CODE                      STATE      PC NO  \
# min         S01  Andaman & Nicobar Islands   1.000000
# max         U07                West Bengal  80.000000
# mean        NaN                        NaN  18.968692
#
#      PARLIAMENTARY CONSTITUENCY  Total voters  Total_Electors  POLL PERCENTAGE
# min              ARUNACHAL EAST  4.324200e+04    4.992200e+04        25.860000
# max                   Zahirabad  1.624859e+06    3.183083e+06        88.360000
# mean                        NaN  1.020581e+06    1.536064e+06        67.319816

# %%
electors.groupby(['STATE'])['POLL PERCENTAGE'].agg(['min','max','mean'])
# Out:
#                              min    max       mean
# STATE
# Andaman & Nicobar Islands  70.67  70.67  70.670000
# Andhra Pradesh             51.05  85.16  75.816190
# Arunachal Pradesh          75.60  84.16  79.880000
# Assam                      75.46  88.36  79.801429
# Bihar                      45.36  67.60  56.487500
# Chandigarh                 73.71  73.71  73.710000
# Chhattisgarh               59.32  77.96  69.520909
# Dadra & Nagar Haveli       84.09  84.09  84.090000
# Daman & Diu                78.01  78.01  78.010000
# Goa                        75.27  78.95  77.110000
# Gujarat                    52.62  74.94  63.668846
# Haryana                    64.98  77.04  71.490000
# Himachal Pradesh           63.15  66.98  64.420000
# Jammu & Kashmir            25.86  71.40  50.696667
# Jharkhand                  54.32  70.94  63.967857
# Karnataka                  55.64  77.15  67.753214
# Kerala                     65.81  81.21  74.015500
# ...

# %%
electors.std()
# Out:
# PC NO                  16.560438
# Total voters       192903.356889
# Total_Electors     288114.433624
# POLL PERCENTAGE        10.316871
# dtype: float64
